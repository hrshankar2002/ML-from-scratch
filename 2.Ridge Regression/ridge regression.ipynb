# %% [markdown]
# ### L2 Regularization

# %% [markdown]
# Linear regression using Scikit Learn

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
# random regression dataset generation, bi-dimensional dataset
X, y = make_regression(n_samples=100, n_features=1, n_informative=1,
                       n_targets=1, noise=20, random_state=13)

# %%
plt.scatter (X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit (X, y)
m = (lr.coef_)
b = (lr.intercept_)
plt.scatter(X, y,color = 'blue')
plt.plot(list(range(-2, 4)), [m * x + b for x in range(-2, 4)], color = "red")
plt.show()
# Out:
# [27.82809103]
# -2.29474455867698

# %% [markdown]
# Ridge regression using Scikit Learn

# %%
from sklearn.linear_model import Ridge

# %%
rr = Ridge (alpha=10)
rr.fit (X, y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [24.9546267]
# -2.126913003523574

# %%
rr1 = Ridge (alpha=100)
rr1.fit (X, y)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033313

# %%
plt.plot(X,y,'b.')
plt.plot(X,lr.predict(X),color='red',label='alpha=0')
plt.plot(X,rr.predict(X),color='green',label='alpha=10')
plt.plot(X,rr1.predict(X),color='orange',label='alpha=100')
plt.legend()

# %% [markdown]
# Ride regression from scratch on bi dimensional dataset

# %%
class Ridge :
    
    def __init__(self, alpha = 0.1):
        self.alpha = alpha
        self.m = None 
        self.b = None
        
    def fit (self, X_train, y_train):
        num = 0 
        den = 0
    
        for i in range (X_train.shape[0]):
            num += (y_train[i] - y_train.mean()) * (X_train[i] - X_train.mean())
            den += (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean())
        
        self.m = num/(den + self.alpha)
        self.b = y_train.mean() - (self.m * X_train.mean())
        
        return self.m, self.b
    
    def predict (X_test):
        pass

# %%
reg = Ridge(alpha=0)
m1, b1 = reg.fit(X, y)

# %%
reg = Ridge(alpha=10)
m2, b2 = reg.fit(X, y)

# %%
reg = Ridge(alpha=100)
m3, b3 = reg.fit(X, y)

# %%
plt.scatter(X, y,color = 'blue')
plt.plot(list(range(-2, 4)), [m1 * x + b1 for x in range(-2, 4)], color = "red", label = 'alpha:0')
plt.plot(list(range(-2, 4)), [m2 * x + b2 for x in range(-2, 4)], color = "green", label = 'alpha:10')
plt.plot(list(range(-2, 4)), [m3 * x + b3 for x in range(-2, 4)], color = "pink", label = 'alpha:100')
plt.legend()

# %% [markdown]
# Ridge regression from scratch on n-dimensional datasets
